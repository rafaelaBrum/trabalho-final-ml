# %%
#importando pacotes úteis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dt_2apli = pd.read_excel('Dataset.xlsx', sheet_name='Dataset AM 2 aplicações')
dt_3apli = pd.read_excel('Dataset.xlsx', sheet_name='Dataset AM 3 aplicações')
dt_aplicacoes = pd.read_excel('Dataset.xlsx', sheet_name='Score Acumulado Aplicações')

# %%
dt_2apli
# Out:
#       Id  Aplicação 1 - SLLC  Aplicação 1 - DRAM  Aplicação 1 - NET  \
# 0      1            1.000000            0.000000           0.100000
# 1      2            1.000000            0.000000           0.100000
# 2      3            1.000000            0.000000           0.100000
# 3      4            1.000000            0.000000           0.100000
# 4      5            1.000000            0.000000           0.100000
# ..   ...                 ...                 ...                ...
# 221  222            0.030208            0.000405           0.007904
# 222  223            0.030208            0.000405           0.007904
# 223  224            0.030208            0.000405           0.007904
# 224  225            0.030208            0.000405           0.007904
# 225  226            0.030208            0.000405           0.007904
#
#      Aplicação 2 - SLLC  Aplicação 2 - DRAM  Aplicação 2 - NET  SlowDown
# 0              1.000000            0.000000           0.100000  1.423619
# ...

# %%
dt_3apli
# Out:
#       Id  Aplicação 1 - SLLC  Aplicação 1 - DRAM  Aplicação 1 - NET  \
# 0    217            0.015291            0.000045           0.037801
# 1    337            0.015291            0.000045           0.037801
# 2    208            0.006728            0.015766           0.000000
# 3    305            0.006728            0.015766           0.000000
# 4    349            0.015291            0.000045           0.037801
# ..   ...                 ...                 ...                ...
# 380   86            0.900000            0.000000           0.500000
# 381   31            1.000000            0.000000           0.100000
# 382  120            0.700000            0.100000           0.400000
# 383  111            1.000000            0.000000           0.300000
# 384    1            1.000000            0.000000           0.100000
#
#      Aplicação 2 - SLLC  Aplicação 2 - DRAM  Aplicação 2 - NET  \
# 0              0.015291            0.000045           0.037801
# ...

# %%
dt_aplicacoes
# Out:
#      Application  Score - SLLC  Score - DRAM  Score - NET
# 0           S1.6      1.000000      0.000000     0.100000
# 1           S2.6      0.500000      0.100000     0.100000
# 2           S3.6      0.100000      0.100000     0.100000
# 3           S4.6      0.300000      1.000000     0.100000
# 4           S5.6      0.100000      0.500000     0.100000
# 5           S6.6      0.500000      0.500000     0.100000
# 6           S7.6      1.000000      0.000000     1.000000
# 7           S8.6      0.500000      0.100000     1.000000
# 8           S9.6      0.100000      0.100000     1.000000
# 9          S10.6      0.300000      1.000000     1.000000
# 10         S11.6      0.100000      0.500000     1.000000
# 11         S12.6      0.500000      0.500000     1.000000
# 12         S13.6      1.000000      0.000000     0.500000
# 13         S14.6      0.500000      0.100000     0.500000
# 14         S15.6      0.100000      0.100000     0.500000
# ...

# %%
plt.hist(dt_aplicacoes['Score - SLLC'], bins=[0, 0.2, 0.4, 0.6, 0.8, 1])
# Out:
# (array([34.,  7.,  8.,  3.,  6.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  <a list of 5 Patch objects>)

# %%
plt.hist(dt_aplicacoes['Score - DRAM'], bins=[0, 0.2, 0.4, 0.6, 0.8, 1])
# Out:
# (array([45.,  1.,  6.,  0.,  6.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  <a list of 5 Patch objects>)

# %%
plt.hist(dt_aplicacoes['Score - NET'], bins=[0, 0.2, 0.4, 0.6, 0.8, 1])
# Out:
# (array([33.,  7., 12.,  0.,  6.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  <a list of 5 Patch objects>)

# %%
dt_2apli['SlowDown'] = (dt_2apli['SlowDown'] - dt_2apli['SlowDown'].min())/(dt_2apli['SlowDown'].max()-dt_2apli['SlowDown'].min())

# %%
plt.hist(dt_2apli['SlowDown'], bins=[0, 0.2, 0.4, 0.6, 0.8, 1])
# Out:
# (array([120.,  68.,  28.,   6.,   4.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  <a list of 5 Patch objects>)

# %%
dt_3apli['SlowDown'] = (dt_3apli['SlowDown'] - dt_3apli['SlowDown'].min())/(dt_3apli['SlowDown'].max()-dt_3apli['SlowDown'].min())

# %%
plt.hist(dt_3apli['SlowDown'], bins=[0, 0.2, 0.4, 0.6, 0.8, 1])
# Out:
# (array([226.,  73.,  63.,  17.,   6.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  <a list of 5 Patch objects>)
